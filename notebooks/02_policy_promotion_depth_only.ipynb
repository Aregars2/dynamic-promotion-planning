# %% [markdown]
# # Policy promotion-depth PPML only
#
# Fits only the `product_promotion_depth` PPML model required for the policy workflow and writes the ex-ante fixed-grid artifact consumed by Notebook 06. It does not run rolling-model comparison, descriptive analysis, behavioral calibration, or policy optimization.

# %%
from pathlib import Path
import sys

ROOT = next(path for path in [Path.cwd(), *Path.cwd().parents] if (path / 'pyproject.toml').is_file())
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from scripts.fit_policy_promotion_depth import run

# %%
artifact_path = run()
artifact_path
